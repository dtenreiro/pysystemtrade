# %%
# %matplotlib inline

# %%
run prebakedsystems.py
# Out:
# Configuring sim logging
# Private configuration '/Users/dtb/Dev/src/remote-projects/pysystemtrade/private/private_config.yaml' is missing or misconfigured; no problem if running in sim mode
# System base_system with .config, .data, and .stages: accounts, portfolio, positionSize, combForecast, forecastScaleCap, rules, rawdata
# 2026-04-21 03:50:44 DEBUG base_system Following instruments are 'duplicate_markets' ['Another_thing', 'bad_thing']
# 2026-04-21 03:50:44 DEBUG base_system Following instruments are marked as 'ignore_instruments': not included: ['EXAMPLE']
# 2026-04-21 03:50:44 DEBUG base_system Following instruments removed entirely from sim: ['Another_thing', 'EXAMPLE', 'bad_thing']
# 2026-04-21 03:50:44 DEBUG base_system {'stage': 'portfolio', 'instrument_code': 'SOFR'} Calculating notional position for SOFR
# 2026-04-21 03:50:44 INFO base_system {'stage': 'portfolio', 'instrument_code': 'SOFR'} Calculating instrument weights
# ...
